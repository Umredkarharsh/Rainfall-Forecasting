# %% [markdown]
# # Basic Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('/content/drive/MyDrive/Internship Project/Project 06 Rain Forcasting/Copy of mumbai-monthly-rains.csv')
df.head(10)
# Out:
#    Year        Jan       Feb        Mar     April         May        June  \
# 0  1901  13.116602  0.000000   0.000000  3.949669   17.139791  640.714036
# 1  1902   0.000000  0.000000   0.000000  0.000000    0.355001  247.998782
# 2  1903   0.000000  0.000000   0.844034  0.000000  220.568740  370.849048
# 3  1904   0.000000  0.000000  11.381769  0.000000    0.000000  723.081969
# 4  1905   0.662561  1.713452   0.000000  0.000000    0.000000  123.870892
# 5  1906   0.000000  3.306695   0.000000  0.000000    0.000000  321.645121
# 6  1907   2.517730  2.979147   0.000000  6.936270    0.000000  631.677035
# 7  1908   1.780360  2.197116   0.291248  0.000000    0.350077  333.986040
# 8  1909   0.000000  0.000000   0.000000  0.780104    0.000000  643.826825
# 9  1910   0.000000  0.000000   0.000000  0.000000    3.047779  468.055059
#
#           July         Aug        Sept         Oct        Nov        Dec  \
# 0   888.369692  545.045796   64.271513    9.871696   0.000000   0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 14 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Year    121 non-null    int64
#  1   Jan     121 non-null    float64
#  2   Feb     121 non-null    float64
#  3   Mar     121 non-null    float64
#  4   April   121 non-null    float64
#  5   May     121 non-null    float64
#  6   June    121 non-null    float64
#  7   July    121 non-null    float64
#  8   Aug     121 non-null    float64
#  9   Sept    121 non-null    float64
#  10  Oct     121 non-null    float64
#  11  Nov     121 non-null    float64
#  12  Dec     121 non-null    float64
#  13  Total   121 non-null    float64
# dtypes: float64(13), int64(1)
# memory usage: 13.4 KB

# %%
df.columns=[i.lower() for i in df.columns]

# %%
print('Check duplicated value :-',df.duplicated().sum())
print('check null value :-',df.isnull().sum())
# Out:
# Check duplicated value :- 0
# check null value :- year     0
# jan      0
# feb      0
# mar      0
# april    0
# may      0
# june     0
# july     0
# aug      0
# sept     0
# oct      0
# nov      0
# dec      0
# total    0
# dtype: int64

# %%
each=[]
for each_year in df['year'].unique():
  each.append(each_year)
print('Unique years:-',each)
print('How many unique years have :-',df['year'].value_counts().sum())
# Out:
# Unique years:- [1901, 1902, 1903, 1904, 1905, 1906, 1907, 1908, 1909, 1910, 1911, 1912, 1913, 1914, 1915, 1916, 1917, 1918, 1919, 1920, 1921, 1922, 1923, 1924, 1925, 1926, 1927, 1928, 1929, 1930, 1931, 1932, 1933, 1934, 1935, 1936, 1937, 1938, 1939, 1940, 1941, 1942, 1943, 1944, 1945, 1946, 1947, 1948, 1949, 1950, 1951, 1952, 1953, 1954, 1955, 1956, 1957, 1958, 1959, 1960, 1961, 1962, 1963, 1964, 1965, 1966, 1967, 1968, 1969, 1970, 1971, 1972, 1973, 1974, 1975, 1976, 1977, 1978, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1986, 1987, 1988, 1989, 1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021]
# How many unique years have :- 121

# %%
df.describe().T
# Out:
#        count         mean         std          min          25%          50%  \
# year   121.0  1961.000000   35.073732  1901.000000  1931.000000  1961.000000
# jan    121.0     1.567235    6.462247     0.000000     0.000000     0.000000
# feb    121.0     0.929358    3.077050     0.000000     0.000000     0.000000
# mar    121.0     0.869231    2.890032     0.000000     0.000000     0.000000
# april  121.0     1.428458    7.371307     0.000000     0.000000     0.000000
# may    121.0    18.183632   48.628812     0.000000     0.000000     0.355001
# june   121.0   517.854402  251.067016    61.058662   324.094617   482.449872
# july   121.0   757.407412  285.836188   103.209194   540.745923   788.403637
# aug    121.0   465.600818  249.072915    87.493370   268.002392   445.870342
# sept   121.0   312.885747  205.135368    36.313545   149.584208   269.276549
# oct    121.0    73.983526   96.686113     0.000000     9.871696    43.479170
# ...

# %%
correlation_matrix = df[['jan', 'feb', 'mar', 'april', 'may', 'june', 'july', 'aug', 'sept', 'oct', 'nov', 'dec','total']].corr()
plt.figure(figsize=(10, 6))
sns.heatmap(correlation_matrix, annot=True)
plt.title('Monthly Rainfall Correlation Heatmap')
# Out:
# Text(0.5, 1.0, 'Monthly Rainfall Correlation Heatmap')

# %%
df_1=df.copy()

# %% [markdown]
# # Outliers Treatments

# %% [markdown]
# **Outliers Handling Testing**

# %%
rainfall_months=df_1.drop(columns=['year','total'])

rainfall_melted = rainfall_months.melt(var_name='Month', value_name='Rainfall')

fig=px.box(rainfall_melted, x='Month',y='Rainfall',title='Distribution of Monthly Rainfall (1901-2021)')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
rainfall_melted
# Out:
#      Month   Rainfall
# 0      jan  13.116602
# 1      jan   0.000000
# 2      jan   0.000000
# 3      jan   0.000000
# 4      jan   0.662561
# ...    ...        ...
# 1447   dec  79.685446
# 1448   dec   0.000000
# 1449   dec   1.172425
# 1450   dec  16.787305
# 1451   dec  90.044602
#
# [1452 rows x 2 columns]

# %% [markdown]
# **Outliers**
# -----------------------------------
# These box plots provide a clear visual comparison of rainfall patterns in Mumbai Monthly:
#
# **January Rainfall:**
#
# - **Very Low Median and IQR:** Both the median and the IQR are extremely low, showing that January is consistently dry in Mumbai.
# - **Few Outliers:** There are very few outliers, and they are not as extreme as in December, indicating that significant rainfall in January is rare.
#
# **February Rainfall:**
#
# - **Low Median, Wider IQR than January, and Moderate Outliers:** The median is low, but the IQR is wider than in January, suggesting slightly more variability in February rainfall. There are also a few outliers, but they are generally less extreme than the highest outliers in December.
#
# - **Slightly Less Skewed Than December:** The distribution is still right-skewed, but less so than December.
#
# **March Rainfall:**
#
# - **Very Low Median and IQR**: The box is extremely short and located very close to zero, showing that most March rainfall amounts are negligible.
#
# - **Numerous Outliers**: Several outliers are present, indicating occasional years with slightly higher (but still relatively low) rainfall in March.
#
# - **Overall**: March is consistently dry, with very little rainfall expected.
#
# **April Rainfall:**
#
# - **Low Median and IQR**: Similar to March, the box is short and near zero, indicating that April is also typically dry.
#
# - **Fewer Outliers**: Compared to March, there are fewer outliers, but the presence of one high outlier suggests that while rare, April can experience significant rainfall events.
#
# - **Overall:** April is predominantly dry, but slightly less so than March, with a very small chance of significant rainfall.
#
# **May Rainfall:**
#
# - **Slightly Higher Median and Wider IQR**: The box is somewhat taller and positioned slightly higher than the previous two months, indicating a potential increase in both the typical amount and variability of rainfall in May.
#
# - **More Frequent Higher Rainfall**: The presence of more data points (including a few outliers) above the box suggests that May experiences more instances of higher rainfall compared to March and April.
# - **Overall**: May marks a transition towards the wetter months, with pre-monsoon showers becoming more frequent and sometimes substantial.
#
# **June Rainfall:**
#
# - **Moderate Variability:** June rainfall shows a moderate degree of variability. While there's a cluster of points in the lower range, there are several instances of significantly higher rainfall.
# - **No Clear Trend:** There's no obvious upward or downward trend in June rainfall over the years.
# - **Typical Monsoon Onset:** June marks the typical onset of the monsoon in Mumbai, so this variability is expected.
#
# **July Rainfall:**
#
# - **Generally High and Consistent:** July rainfall is generally high and relatively consistent. Most data points are clustered in the upper range, indicating substantial rainfall in most Julys.
# - **Less Variability Than June:** Compared to June, July rainfall shows less variability. There are fewer instances of exceptionally high or low rainfall.
# - **Peak Monsoon Month:** July is typically the peak monsoon month in Mumbai, which is reflected in the consistently high rainfall amounts.
#
# **August Rainfall:**
#
# - **High and Relatively Consistent:** August, like July, shows high and relatively consistent rainfall. Most data points are clustered in the upper range.
# - **Similar Pattern to July:** The rainfall pattern in August is quite similar to July, with consistently high amounts and less variability than June.
#
# **September Rainfall:**
#
# - **Decreasing Rainfall:** September shows a wider spread of data points compared to July and August, with a noticeable decrease in rainfall amounts in some years.
# - **More Variability Than July/August:** September rainfall is more variable than July or August, indicating the start of the monsoon's withdrawal.
# - **End of Monsoon:** September marks the end of the main monsoon season in Mumbai, which is reflected in the decreasing rainfall trend.
#
# **October Rainfall:**
# - High variability, moderately high typical rainfall, and frequent exceptionally high rainfall events (outliers). The rainfall distribution is skewed towards higher amounts.This confirms the high variability we saw in the line plots.
#
# - The plot shows several outliers on the higher end, reinforcing the observation that October can have exceptionally high rainfall events. These outliers are far above the upper whisker, highlighting their unusualness.
#
# **November Rainfall:**
# - Low variability, low typical rainfall, with occasional (but rare) higher rainfall events. The rainfall distribution is also skewed towards higher amounts, but less so than October. This confirms the consistency and generally low rainfall in November.
#
# **December Rainfall:**
#
# - **Low Median, Wide IQR, and High Outliers:** The box is short and close to zero, indicating that the median and interquartile range (IQR) of December rainfall are low. However, there are several significant outliers, some reaching very high values. This confirms that while most Decembers are dry, there's a chance of substantial rainfall.
#
# - **Skewness:** The distribution is heavily right-skewed, meaning there's a long tail of higher rainfall amounts.

# %% [markdown]
# **| Removing Outliers**

# %%
rainfall_columns=df_1.drop(columns=['year','total'])

def cap_outliers(df, columns):
    for col in columns:

        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1


        lower_bound = Q1 - 1.5 * IQR
        upper_bound = Q3 + 1.5 * IQR

        df[col] = np.where(df[col] > upper_bound, upper_bound, df[col])
        df[col] = np.where(df[col] < lower_bound, lower_bound, df[col])

    return df

df_cleaned = cap_outliers(df_1, rainfall_columns)

# %%
df_cleaned
# Out:
#      year  jan       feb  mar     april        may        june         july  \
# 0    1901  0.0  0.000000  0.0  0.485413  10.520805  640.714036   888.369692
# 1    1902  0.0  0.000000  0.0  0.000000   0.355001  247.998782   408.433730
# 2    1903  0.0  0.000000  0.0  0.000000  10.520805  370.849048   902.447896
# 3    1904  0.0  0.000000  0.0  0.000000   0.000000  723.081969   390.886799
# 4    1905  0.0  0.380745  0.0  0.000000   0.000000  123.870892   581.827975
# ..    ...  ...       ...  ...       ...        ...         ...          ...
# 116  2017  0.0  0.000000  0.0  0.000000   1.043890  584.946748   702.386594
# 117  2018  0.0  0.000000  0.0  0.000000   0.000000  846.855987   913.470461
# 118  2019  0.0  0.000000  0.0  0.000000   0.000000  412.763730  1302.466441
# 119  2020  0.0  0.000000  0.0  0.000000   0.000000  439.814569  1328.766631
# 120  2021  0.0  0.380745  0.0  0.002233  10.520805  796.307275   981.146645
#
# ...

# %%
rainfall_columns=df_cleaned.drop(columns=['year','total'])

rainfall_melted = rainfall_columns.melt(var_name='Month', value_name='Rainfall')

fig_1=px.box(rainfall_melted, x='Month',y='Rainfall',title='Distribution of Monthly Rainfall (1901-2021)')

fig_1.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
rainfall_melted
# Out:
#      Month  Rainfall
# 0      jan  0.000000
# 1      jan  0.000000
# 2      jan  0.000000
# 3      jan  0.000000
# 4      jan  0.000000
# ...    ...       ...
# 1447   dec  0.440373
# 1448   dec  0.000000
# 1449   dec  0.440373
# 1450   dec  0.440373
# 1451   dec  0.440373
#
# [1452 rows x 2 columns]

# %% [markdown]
# **1. Removing Outliers Using IQR (Interquartile Range) Method:**
# - Outliers are typically defined as values falling outside 1.5 times the IQR above Q3 or below Q1.
#
# - In this case, for each month, rainfall data points that fall below the lower bound or above the upper bound are considered outliers and removed.
#
# - The new boxplot will have no outliers, and the range of whiskers (the lines extending from the box) will be shorter, reflecting the more typical rainfall patterns.
#
# - The data will look more condensed, and extreme high or low rainfall values will no longer be visible.
# Interpretation is Removing outliers simplifies the data by focusing on the core range of rainfall for each month, making it easier to spot patterns in typical monthly rainfall.
#
# **2. Capping Outliers:-**
#
# - Instead of removing outliers, this method caps them. Values beyond the upper or lower bounds (as determined by the IQR) are set to the respective bounds. This preserves all data points but restricts extreme values.
#
# - The whiskers will extend only up to the capped values, giving a smoother representation of the data.
#
# - Interpretation is Capping reduces the impact of extreme values while keeping the data intact. The boxplot will still display variation, but the risk of highly skewed results due to outliers is reduced.

# %% [markdown]
# **Summary of Handling Outliers:-**
#
# - **Removing outliers using IQR**: This method strictly eliminates outliers, focusing on typical rainfall distributions, but at the cost of potentially discarding important extreme values.
#
# - **Capping outliers**: This retains all data but limits the effect of extreme values, ensuring that outliers don’t skew the results too much while preserving the dataset's completeness.

# %%
df_cleaned.describe().T
# Out:
#        count         mean         std          min          25%          50%  \
# year   121.0  1961.000000   35.073732  1901.000000  1931.000000  1961.000000
# jan    121.0     0.000000    0.000000     0.000000     0.000000     0.000000
# feb    121.0     0.093103    0.161254     0.000000     0.000000     0.000000
# mar    121.0     0.000000    0.000000     0.000000     0.000000     0.000000
# april  121.0     0.114677    0.199179     0.000000     0.000000     0.000000
# may    121.0     2.939205    4.185707     0.000000     0.000000     0.355001
# june   121.0   517.767141  250.822829    61.058662   324.094617   482.449872
# july   121.0   757.407412  285.836188   103.209194   540.745923   788.403637
# aug    121.0   464.017624  244.667307    87.493370   268.002392   445.870342
# sept   121.0   308.214803  192.066548    36.313545   149.584208   269.276549
# oct    121.0    65.218892   66.440947     0.000000     9.871696    43.479170
# ...

# %% [markdown]
# **Create copy for next round of insights**

# %%
df_nxt=df_cleaned.copy()

# %%
df_1.head()
# Out:
#    year  jan       feb  mar     april        may        june        july  \
# 0  1901  0.0  0.000000  0.0  0.485413  10.520805  640.714036  888.369692
# 1  1902  0.0  0.000000  0.0  0.000000   0.355001  247.998782  408.433730
# 2  1903  0.0  0.000000  0.0  0.000000  10.520805  370.849048  902.447896
# 3  1904  0.0  0.000000  0.0  0.000000   0.000000  723.081969  390.886799
# 4  1905  0.0  0.380745  0.0  0.000000   0.000000  123.870892  581.827975
#
#           aug        sept         oct        nov       dec        total
# 0  545.045796   64.271513    9.871696   0.000000  0.000000  2182.478796
# 1  566.595863  688.913455   28.654092   0.488864  0.440373  1960.966334
# 2  602.420828  264.589816  157.892877   0.000000  0.000000  2519.613240
# 3  191.581927   85.704754   38.679948   0.000000  0.000000  1441.317168
# 4  167.382149  172.297723    7.365924  23.432885  0.000000  1080.024250

# %%
print("Rainfall total all over the years:-\n",df_cleaned['total'].describe())
# Out:
# Rainfall total all over the years:-
#  count     121.000000
# mean     2168.115709
# std       533.263926
# min      1058.840525
# 25%      1834.996957
# 50%      2126.054987
# 75%      2478.558089
# max      3563.259531
# Name: total, dtype: float64

# %%
total_minimum_rainfall=df_cleaned['total'].min()
total_maximum_rainfall=df_cleaned['total'].max()
total_average_rainfall=df_cleaned['total'].mean()
print(f'Annual Minimum Rainfall:-{total_minimum_rainfall:.2f}mm')
print(f'Annual Maximum Rainfall:-{total_maximum_rainfall:.2f}mm')
print(f'Annual Average Rainfall:-{total_average_rainfall:.2f}mm')
# Out:
# Annual Minimum Rainfall:-1058.84mm
# Annual Maximum Rainfall:-3563.26mm
# Annual Average Rainfall:-2168.12mm

# %% [markdown]
# ## Visualization Of Annual Rainfall

# %%
df_cleaned.groupby("year").sum()['total'];
fig = px.line(df_cleaned, x='year',y='total',
              title='Total Rainfall in Mumbai(1901-2021)',
              labels={'total':'Total Rainfall(mm)','year':'Years'},
              markers=True)
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# ## Monthly Rainfall

# %%
monthly_rainfall_melted = df_cleaned.melt(id_vars='year',value_vars=['jan', 'feb', 'mar', 'april', 'may', 'june', 'july', 'aug', 'sept', 'oct', 'nov', 'dec'],
                                                 var_name='Month', value_name='Rainfall (mm)')

# Create the Plotly Express plot
fig = px.line(monthly_rainfall_melted, x='year', y='Rainfall (mm)', color='Month',
              title='Monthly Rainfall in Mumbai (Yearly)',
              labels={'Rainfall (mm)': 'Total Monthly Rainfall (mm)', 'year': 'Year'})

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # Data Split into Seasonal part
#
# ---

# %%
# Creating seasonal type of sample dataset
winter=df_cleaned[['year','dec','jan','feb','total']]
summer=df_cleaned[['year','mar','april','may','total']]
monsoon=df_cleaned[['year','june','july','aug','sept','total']]
post_monsoon=df_cleaned[['year','oct','nov','total']]

# %% [markdown]
# ## post_monsoon

# %%
post_monsoon.head()
# Out:
#    year         oct        nov        total
# 0  1901    9.871696   0.000000  2182.478796
# 1  1902   28.654092   0.488864  1960.966334
# 2  1903  157.892877   0.000000  2519.613240
# 3  1904   38.679948   0.000000  1441.317168
# 4  1905    7.365924  23.432885  1080.024250

# %%
post_monsoon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    121 non-null    int64
#  1   oct     121 non-null    float64
#  2   nov     121 non-null    float64
#  3   total   121 non-null    float64
# dtypes: float64(3), int64(1)
# memory usage: 3.9 KB

# %%
post_monsoon.describe()
# Out:
#               year         oct         nov        total
# count   121.000000  121.000000  121.000000   121.000000
# mean   1961.000000   65.218892    6.472508  2168.115709
# std      35.073732   66.440947    9.306821   533.263926
# min    1901.000000    0.000000    0.000000  1058.840525
# 25%    1931.000000    9.871696    0.000000  1834.996957
# 50%    1961.000000   43.479170    1.066086  2126.054987
# 75%    1991.000000   98.235161    9.373154  2478.558089
# max    2021.000000  230.780358   23.432885  3563.259531

# %%
fig,axes=plt.subplots(1,2,figsize=(25,5))

sns.scatterplot(data=post_monsoon,x='year',y='oct',ax=axes[0])
axes[0].set_title('October Rainfall vs. year')
sns.scatterplot(data=post_monsoon,x='year',y='nov',ax=axes[1])
axes[1].set_title('November Rainfall vs. year')
fig.suptitle('Scatter Plots')
plt.tight_layout()

plt.show()

# %%
fig,axes=plt.subplots(1,2,figsize=(25,5))

sns.lineplot(data=post_monsoon,x='year',y='oct',ax=axes[0])
axes[0].set_title('October Rainfall vs. year')
sns.lineplot(data=post_monsoon,x='year',y='nov',ax=axes[1])
axes[1].set_title('November Rainfall vs. year')
fig.suptitle('Line Plots')
plt.tight_layout()

plt.show()

# %%
monthly_rainfall_melted = post_monsoon.melt(id_vars='year',value_vars=['oct', 'nov'],
                                                 var_name='Month', value_name='Rainfall (mm)')

# Create the Plotly Express plot
fig = px.line(monthly_rainfall_melted, x='year', y='Rainfall (mm)', color='Month',
              title='Post Monsoon Rainfall in Mumbai (Yearly)',
              labels={'Rainfall (mm)': 'Total Monthly Rainfall (mm)', 'year': 'Year'})

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Report**
#
# ---------------------------------------------
# This chart displays the post-monsoon rainfall in Mumbai from 1900 to 2020, specifically for the months of October and November
#
# * **November Rainfall**: November rainfall remains consistently low, generally below 25 mm, suggesting a drier period compared to October.
#
#    November generally experiences low rainfall, indicating a transition to a drier period. This information is crucial for agriculture and water resource planning, as it suggests a potential need for irrigation and water conservation.
#
# * **October Rainfall**: The blue line, representing October rainfall, shows significantly higher levels of precipitation compared to November (red line) throughout the entire period.

# %%
fig,axes=plt.subplots(1,2,figsize=(25,5))

sns.distplot(post_monsoon['oct'],ax=axes[0])
axes[0].set_title('October Rainfall')
sns.distplot(post_monsoon['nov'],ax=axes[1])
axes[1].set_title('November Rainfall')
fig.suptitle('Post Monsoon HistoPlots')
plt.tight_layout()

plt.show()

# %% [markdown]
# ## summer

# %%
summer.head()
# Out:
#    year  mar     april        may        total
# 0  1901  0.0  0.485413  10.520805  2182.478796
# 1  1902  0.0  0.000000   0.355001  1960.966334
# 2  1903  0.0  0.000000  10.520805  2519.613240
# 3  1904  0.0  0.000000   0.000000  1441.317168
# 4  1905  0.0  0.000000   0.000000  1080.024250

# %%
summer.describe()
# Out:
#               year    mar       april         may        total
# count   121.000000  121.0  121.000000  121.000000   121.000000
# mean   1961.000000    0.0    0.114677    2.939205  2168.115709
# std      35.073732    0.0    0.199179    4.185707   533.263926
# min    1901.000000    0.0    0.000000    0.000000  1058.840525
# 25%    1931.000000    0.0    0.000000    0.000000  1834.996957
# 50%    1961.000000    0.0    0.000000    0.355001  2126.054987
# 75%    1991.000000    0.0    0.194165    4.208322  2478.558089
# max    2021.000000    0.0    0.485413   10.520805  3563.259531

# %%
fig,axes=plt.subplots(1,3,figsize=(25,5))

sns.scatterplot(data=summer,x='year',y='mar',ax=axes[0])
axes[0].set_title('March Rainfall vs. year')
sns.scatterplot(data=summer,x='year',y='april',ax=axes[1])
axes[1].set_title('April Rainfall vs. year')
sns.scatterplot(data=summer,x='year',y='may',ax=axes[2])
axes[2].set_title('May Rainfall vs. year')
fig.suptitle('Scatter Plots')
plt.tight_layout()
plt.show()

# %%
fig,axes=plt.subplots(1,3,figsize=(25,5))

sns.lineplot(data=summer,x='year',y='mar',ax=axes[0])
axes[0].set_title('March Rainfall vs. year')
sns.lineplot(data=summer,x='year',y='april',ax=axes[1])
axes[1].set_title('April Rainfall vs. year')
sns.lineplot(data=summer,x='year',y='may',ax=axes[2])
axes[2].set_title('May Rainfall vs. year')
fig.suptitle('Line Plots')
plt.tight_layout()

plt.show()

# %%
fig,axes=plt.subplots(1,3,figsize=(25,5))

sns.boxplot(data=summer,y='mar',ax=axes[0])
axes[0].set_title('March Rainfall ')
sns.boxplot(data=summer,y='april',ax=axes[1])
axes[1].set_title('April Rainfall')
sns.boxplot(data=summer,y='may',ax=axes[2])
axes[2].set_title('May Rainfall ')
fig.suptitle('Box Plots')
plt.tight_layout()

plt.show()

# %%
monthly_rainfall_melted = summer.melt(id_vars='year',
                                                 value_vars=['mar', 'april','may'],
                                                 var_name='Month', value_name='Rainfall (mm)')

# Create the Plotly Express plot
fig = px.line(monthly_rainfall_melted, x='year', y='Rainfall (mm)', color='Month',
              title='Monthly Rainfall in Mumbai (Yearly)',
              labels={'Rainfall (mm)': 'Total Monthly Rainfall (mm)', 'year': 'Year'})

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig,axes=plt.subplots(1,3,figsize=(25,5))

sns.distplot(summer['mar'],ax=axes[0])
axes[0].set_title('March Rainfall')
sns.distplot(summer['april'],ax=axes[1])
axes[1].set_title('April Rainfall')
sns.distplot(summer['may'],ax=axes[2])
axes[2].set_title('May Rainfall')
fig.suptitle('HistoPlots')
plt.tight_layout()

plt.show()

# %% [markdown]
# ## Winter

# %%
winter.head()
# Out:
#    year       dec  jan       feb        total
# 0  1901  0.000000  0.0  0.000000  2182.478796
# 1  1902  0.440373  0.0  0.000000  1960.966334
# 2  1903  0.000000  0.0  0.000000  2519.613240
# 3  1904  0.000000  0.0  0.000000  1441.317168
# 4  1905  0.000000  0.0  0.380745  1080.024250

# %%
winter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    121 non-null    int64
#  1   dec     121 non-null    float64
#  2   jan     121 non-null    float64
#  3   feb     121 non-null    float64
#  4   total   121 non-null    float64
# dtypes: float64(4), int64(1)
# memory usage: 4.9 KB

# %%
winter.describe()
# Out:
#               year         dec    jan         feb        total
# count   121.000000  121.000000  121.0  121.000000   121.000000
# mean   1961.000000    0.108225    0.0    0.093103  2168.115709
# std      35.073732    0.185647    0.0    0.161254   533.263926
# min    1901.000000    0.000000    0.0    0.000000  1058.840525
# 25%    1931.000000    0.000000    0.0    0.000000  1834.996957
# 50%    1961.000000    0.000000    0.0    0.000000  2126.054987
# 75%    1991.000000    0.176149    0.0    0.152298  2478.558089
# max    2021.000000    0.440373    0.0    0.380745  3563.259531

# %%
fig,axes=plt.subplots(1,3,figsize=(25,5))

sns.scatterplot(data=winter,x='year',y='dec',ax=axes[0])
axes[0].set_title('December Rainfall vs. year')
sns.scatterplot(data=winter,x='year',y='jan',ax=axes[1])
axes[1].set_title('January Rainfall vs. year')
sns.scatterplot(data=winter,x='year',y='feb',ax=axes[2])
axes[2].set_title('February Rainfall vs. year')
fig.suptitle('Scatter Plots')
plt.tight_layout()
plt.show()

# %%
fig,axes=plt.subplots(1,3,figsize=(25,5))

sns.lineplot(data=winter,x='year',y='dec',ax=axes[0])
axes[0].set_title('December Rainfall vs. year')
sns.lineplot(data=winter,x='year',y='jan',ax=axes[1])
axes[1].set_title('January Rainfall vs. year')
sns.lineplot(data=winter,x='year',y='feb',ax=axes[2])
axes[2].set_title('February Rainfall vs. year')
fig.suptitle('Line Plots')
plt.tight_layout()

plt.show()

# %%
monthly_rainfall_melted = winter.melt(id_vars='year',
                                                 value_vars=['dec', 'jan','feb'],
                                                 var_name='Month', value_name='Rainfall (mm)')

# Create the Plotly Express plot
fig = px.line(monthly_rainfall_melted, x='year', y='Rainfall (mm)', color='Month',
              title='Monthly Rainfall in Mumbai (Yearly)',
              labels={'Rainfall (mm)': 'Total Monthly Rainfall (mm)', 'year': 'Year'})

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig,axes=plt.subplots(1,3,figsize=(25,5))

sns.distplot(winter['dec'],ax=axes[0])
axes[0].set_title('December Rainfall')
sns.distplot(winter['jan'],ax=axes[1])
axes[1].set_title('January Rainfall')
sns.distplot(winter['feb'],ax=axes[2])
axes[2].set_title('February Rainfall')
fig.suptitle('HistoPlots')
plt.tight_layout()

plt.show()

# %% [markdown]
# ## monsoon

# %%
monsoon.head()
# Out:
#    year        june        july         aug        sept        total
# 0  1901  640.714036  888.369692  545.045796   64.271513  2182.478796
# 1  1902  247.998782  408.433730  566.595863  688.913455  1960.966334
# 2  1903  370.849048  902.447896  602.420828  264.589816  2519.613240
# 3  1904  723.081969  390.886799  191.581927   85.704754  1441.317168
# 4  1905  123.870892  581.827975  167.382149  172.297723  1080.024250

# %%
monsoon.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 121 entries, 0 to 120
# Data columns (total 6 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   year    121 non-null    int64
#  1   june    121 non-null    float64
#  2   july    121 non-null    float64
#  3   aug     121 non-null    float64
#  4   sept    121 non-null    float64
#  5   total   121 non-null    float64
# dtypes: float64(5), int64(1)
# memory usage: 5.8 KB

# %%
monsoon.describe()
# Out:
#               year         june         july          aug        sept  \
# count   121.000000   121.000000   121.000000   121.000000  121.000000
# mean   1961.000000   517.767141   757.407412   464.017624  308.214803
# std      35.073732   250.822829   285.836188   244.667307  192.066548
# min    1901.000000    61.058662   103.209194    87.493370   36.313545
# 25%    1931.000000   324.094617   540.745923   268.002392  149.584208
# 50%    1961.000000   482.449872   788.403637   445.870342  269.276549
# 75%    1991.000000   678.040770   942.616099   604.372615  398.645218
# max    2021.000000  1208.959999  1358.833554  1108.927948  772.236732
#
#              total
# count   121.000000
# mean   2168.115709
# std     533.263926
# min    1058.840525
# 25%    1834.996957
# 50%    2126.054987
# 75%    2478.558089
# max    3563.259531

# %%
fig,axes=plt.subplots(1,4,figsize=(25,5))

sns.scatterplot(data=monsoon,x='june',y='year',ax=axes[0])
axes[0].set_title('June Rainfall vs. year')
sns.scatterplot(data=monsoon,x='july',y='year',ax=axes[1])
axes[1].set_title('July Rainfall vs. year')
sns.scatterplot(data=monsoon,x='aug',y='year',ax=axes[2])
axes[2].set_title('Augest Rainfall vs. year')
sns.scatterplot(data=monsoon,x='sept',y='year',ax=axes[3])
axes[3].set_title('September Rainfall vs. year')
fig.suptitle('Scatter Plots')

plt.tight_layout()
plt.show()

# %%
fig,axes=plt.subplots(1,4,figsize=(25,5))

sns.lineplot(data=monsoon,x='year',y='june',ax=axes[0])
axes[0].set_title('june Rainfall vs. year')
sns.lineplot(data=monsoon,x='year',y='july',ax=axes[1])
axes[1].set_title('july Rainfall vs. year')
sns.lineplot(data=monsoon,x='year',y='aug',ax=axes[2])
axes[2].set_title('Augest Rainfall vs. year')
sns.lineplot(data=monsoon,x='year',y='sept',ax=axes[3])
axes[3].set_title('September Rainfall vs. year')
fig.suptitle('Line Plots')
plt.tight_layout()

plt.show()

# %%
monthly_rainfall_melted = monsoon.melt(id_vars='year',
                                                 value_vars=['june', 'july','aug', 'sept'],
                                                 var_name='Month', value_name='Rainfall (mm)')

# Create the Plotly Express plot
fig = px.line(monthly_rainfall_melted, x='year', y='Rainfall (mm)', color='Month',
              title='Monthly Rainfall in Mumbai (Yearly)',
              labels={'Rainfall (mm)': 'Total Monthly Rainfall (mm)', 'year': 'Year'})

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig,axes=plt.subplots(1,4,figsize=(25,5))

sns.distplot(monsoon['june'],ax=axes[0])
axes[0].set_title('june Rainfall')
sns.distplot(monsoon['july'],ax=axes[1])
axes[1].set_title('july Rainfall')
sns.distplot(monsoon['aug'],ax=axes[2])
axes[2].set_title('Augest Rainfall')
sns.distplot(monsoon['sept'],ax=axes[3])
axes[3].set_title('September Rainfall')
fig.suptitle('HistoPlots')
plt.tight_layout()

plt.show()

# %%
monthly_rainfall_melted = monsoon.melt(id_vars='year',
                                                 value_vars=['june', 'july','aug', 'sept'],
                                                 var_name='Month', value_name='Rainfall (mm)')

# Create the Plotly Express plot
fig = px.line(monthly_rainfall_melted, x='year', y='Rainfall (mm)', color='Month',
              title='Monthly Rainfall in Mumbai (Yearly)',
              labels={'Rainfall (mm)': 'Total Monthly Rainfall (mm)', 'year': 'Year'})

# Show the plot
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
plt.figure(figsize=(25,10))
sns.barplot(data=monsoon,x="year",y="june")
plt.title('June Month Rainfall Every Years')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(25,10))
sns.barplot(data=monsoon,x="year",y="july")
plt.title('July Month Rainfall Every Years')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(25,10))
sns.barplot(data=monsoon,x="year",y="aug")
plt.title('Augest Month Rainfall Every Years')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(25,10))
sns.barplot(data=monsoon,x="year",y="sept")
plt.title('September Month Rainfall Every Years')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# ## More Insights
# -----------------------------

# %%
df_cleaned['post_monsoon']=df_cleaned[['oct','nov']].sum(axis=1)
df_cleaned['summer']=df_cleaned[['mar','april','may']].sum(axis=1)
df_cleaned['winter']=df_cleaned[['dec','jan','feb']].sum(axis=1)
df_cleaned['monsoon']=df_cleaned[['june','july','aug','sept']].sum(axis=1)

seasonal_total=df_cleaned[['post_monsoon','summer','winter','monsoon']].sum()

seasonal_total_df=pd.DataFrame({
    'Seasons':['post_monsoon','summer','winter','monsoon'],
    'Total_Rainfalls(mm)': seasonal_total.values
})

fig= px.bar(seasonal_total_df,
       x='Seasons',
       y='Total_Rainfalls(mm)',
       color='Seasons',
       text='Total_Rainfalls(mm)',
       color_discrete_sequence=['skyblue', 'lightcoral', 'lightgreen', 'orange'],
       title='Total Seasonal Rainfall In Mumbai')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Classification of Yearly Rainfall Data**

# %%
median_rainfall = np.median(df_cleaned['total'])
mad_rainfall = np.median(np.abs(df_cleaned['total'] - median_rainfall))

threshold_low = median_rainfall - 3 * mad_rainfall
threshold_max = median_rainfall + 3 * mad_rainfall

def classify_rainfall(rainfall):
  if rainfall < threshold_low:
    return 'Below Normal'
  elif rainfall > threshold_max:
    return 'Abnormal'
  else:
    return 'Normal'

df_cleaned['classification']=df_cleaned['total'].apply(classify_rainfall)

# %%
fig_2=px.bar(df_cleaned,x='year',y='total',
       color='classification',
       color_discrete_map={'Below Normal': 'orange','Normal':'green','Abnormal':'red'},
       labels={'total':'Total Rainfall','year':'years','classification_MAD':'classification'},
       title='Yearly Rainfall with Classification')
fig_2.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
classification_counts = df_cleaned['classification'].value_counts().reset_index()
classification_counts.columns= ['classification','count']

px.bar(classification_counts, x='classification',y='count',
       color_discrete_map ={
           'Normal' : 'green',
           'Below Normal': 'orange',
           'Abnormal': 'red'
       },
       color='classification',
       title='Number of Years by Rainfall classification'
       )
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Distribution of Rainfall Categories**

# %%
df_cleaned['total'].describe()
# Out:
# count     121.000000
# mean     2168.115709
# std       533.263926
# min      1058.840525
# 25%      1834.996957
# 50%      2126.054987
# 75%      2478.558089
# max      3563.259531
# Name: total, dtype: float64

# %% [markdown]
# The Indian Meteorological Department (IMD) uses a color-coded warning system to indicate the severity of weather conditions. Here are the details of the scale with corresponding numbers for rainfall:
#
# **Green Alert**: No warning. Normal conditions.
#
# **Yellow Alert:** Be aware. Heavy rainfall ranging from 64.5 mm to 115.5 mm in 24 hours.
#
# **Orange Alert:** Be prepared. Very heavy rainfall ranging from 115.6 mm to 204.4 mm in 24 hours.
#
# **Red Alert:** Take action. Extremely heavy rainfall exceeding 204.5 mm in 24 hours.

# %%
def categorize_rainfall(Total):
    if Total < 500:
        return 'Very Low' # Green
    elif 500 <= Total < 1000:
        return 'Low'  # Green
    elif 1000 <= Total < 1800:
        return 'Medium' # Yellow
    elif 1800 <= Total < 2100:
        return 'High'   # Orange
    elif 2100 <= Total < 2500:
        return 'Very High'  # Orange
    else:  Total >= 2500
    return 'Extreme'  #Red


df_cleaned['category'] = df_cleaned['total'].apply(categorize_rainfall)

df_cleaned
# Out:
#      year  jan       feb  mar     april        may        june         july  \
# 0    1901  0.0  0.000000  0.0  0.485413  10.520805  640.714036   888.369692
# 1    1902  0.0  0.000000  0.0  0.000000   0.355001  247.998782   408.433730
# 2    1903  0.0  0.000000  0.0  0.000000  10.520805  370.849048   902.447896
# 3    1904  0.0  0.000000  0.0  0.000000   0.000000  723.081969   390.886799
# 4    1905  0.0  0.380745  0.0  0.000000   0.000000  123.870892   581.827975
# ..    ...  ...       ...  ...       ...        ...         ...          ...
# 116  2017  0.0  0.000000  0.0  0.000000   1.043890  584.946748   702.386594
# 117  2018  0.0  0.000000  0.0  0.000000   0.000000  846.855987   913.470461
# 118  2019  0.0  0.000000  0.0  0.000000   0.000000  412.763730  1302.466441
# 119  2020  0.0  0.000000  0.0  0.000000   0.000000  439.814569  1328.766631
# 120  2021  0.0  0.380745  0.0  0.002233  10.520805  796.307275   981.146645
#
# ...

# %%
fig_3 = px.pie(df_cleaned, names='category', title='Distribution of Rainfall Categories',
             hole=0.3)
fig_3.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
